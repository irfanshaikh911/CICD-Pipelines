# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Shaikh Irfan\Downloads\drive-download-20250419T131102Z-001\kddcup99[GRP A5].csv")
df.head(5)
# Out:
#    duration protocol_type  service flag  src_bytes  dst_bytes  land  \
# 0         0          icmp    ecr_i   SF       1032          0     0
# 1         0          icmp    ecr_i   SF       1032          0     0
# 2         0           tcp  private   S0          0          0     0
# 3         0           tcp     http   SF        345       5419     0
# 4         0           tcp  private   S0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                 255
# 1               0       0    0  ...                 255
# 2               0       0    0  ...                   9
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                   2
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    1.00                    0.00
# 1                    1.00                    0.00
# 2                    0.04                    0.08
# ...

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'lnum_compromised', 'lroot_shell',
#        'lsu_attempted', 'lnum_root', 'lnum_file_creations', 'lnum_shells',
#        'lnum_access_files', 'lnum_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'label'],
#       dtype='object')

# %%
for i in
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12376\1115469300.py in ?()
# ----> 1 df.dtype
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
